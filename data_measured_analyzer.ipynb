# %%
import numpy as np
import csv 
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the text file into a DataFrame
df = pd.read_csv("O:\Projektarbeit\/1904\Testbench\/1000N-0001.csv", sep = ";")

# Display the DataFrame
print(df)
# Out:
#     Timestamp  Distance (mm)  Distance (pixels)  Left Point  Right Point
# 0        0.04     671.000000          24.306046         387         1058
# 1        0.08     674.000742          24.414744         387         1061
# 2        0.12     672.000000          24.342270         387         1059
# 3        0.16     674.000742          24.414744         387         1061
# 4        0.20     674.000000          24.414717         387         1061
# ..        ...            ...                ...         ...          ...
# 92       3.72     720.000000          26.081003         362         1082
# 93       3.76     720.000000          26.081003         362         1082
# 94       3.80     720.000000          26.081003         362         1082
# 95       3.84     720.000000          26.081003         362         1082
# 96       3.88     726.000689          26.298370         361         1087
#
# [97 rows x 5 columns]

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.plot(df['Timestamp'], df['Distance (mm)'], marker='o', linestyle='-')
plt.title('Distance over Time')
plt.xlabel('Timestamp')
plt.ylabel('Distance (mm)')
plt.grid(True)
plt.show()
