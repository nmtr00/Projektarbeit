# %%
import numpy as np
import csv as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Parameters
main_folder = "O:\Projektarbeit\/2504"
input_folder = f"{main_folder}\Recorded"
output_folder = f"{main_folder}\Analyzed"
output_data = f"{main_folder}\Measured_values"

# %%
# Read the text file into a DataFrame
df = pd.read_csv("BeAndFo10001.txt", sep='|', header=None, skiprows=1)

# Display the DataFrame
print(df)
# Out:
#            0          1         2
# 0      0.006  39.324760  0.000029
# 1      0.017  39.778948 -0.000029
# 2      0.026  41.922331 -0.000129
# 3      0.036  40.362477  0.000000
# 4      0.048  41.080117  0.000210
# ...      ...        ...       ...
# 1009  10.687  38.231015  0.013356
# 1010  10.698  42.090416  0.005026
# 1011  10.708  40.827394  0.000238
# 1012  10.720  41.219592 -0.001259
# 1013  10.731  40.792823 -0.001054
#
# [1014 rows x 3 columns]

# %%
# Find the index where all three columns contain specific values
split_index_1 = df[(df[0] == -1) & (df[1] == -1) & (df[2] == -1)].index[0]
split_index_2 = df[(df[0] == -2) & (df[1] == -2) & (df[2] == -2)].index[0]
split_index_3 = df[(df[0] == -3) & (df[1] == -3) & (df[2] == -3)].index[0]

# Split the DataFrame into multiple parts
first_part = df.iloc[:split_index_1]
second_part = df.iloc[split_index_1+1:split_index_2]
third_part = df.iloc[split_index_2+1:split_index_3]
fourth_part = df.iloc[split_index_3+1:]

# Display the parts
print("First part:")
print(first_part)

print("\nSecond part:")
print(second_part)

print("\nThird part:")
print(third_part)

print("\nFourth part:")
print(fourth_part)
# Out:
# First part:
#          0           1         2
# 0    0.006   39.324760  0.000029
# 1    0.017   39.778948 -0.000029
# 2    0.026   41.922331 -0.000129
# 3    0.036   40.362477  0.000000
# 4    0.048   41.080117  0.000210
# ..     ...         ...       ...
# 439  4.643  458.437204  4.583354
# 440  4.653  480.058789  4.593678
# 441  4.665  502.792001  4.603877
# 442  4.676  526.096821  4.614282
# 443  4.686  548.915863  4.624448
#
# [444 rows x 3 columns]
#
# Second part:
#          0            1         2
# 445  4.702   623.086095  4.679933
# 446  4.714   621.497631  4.679880
# 447  4.724   622.544289  4.679837
# 448  4.734   622.453094  4.680147
# 449  4.744   622.588396  4.681025
# ..     ...          ...       ...
# 512  5.424  1569.445133  5.018477
# 513  5.434  1586.365700  5.023370
# 514  5.444  1598.041058  5.028472
# 515  5.456  1614.153385  5.033469
# 516  5.467  1628.431678  5.038290
#
# [72 rows x 3 columns]
#
# Third part:
#          0            1        2
# 518  5.467  1628.431678  5.03829
# 519  5.467  1628.431678  5.03829
#
# Fourth part:
#            0            1         2
# 521    5.477  1622.734070  5.065103
# 522    5.488  1619.985700  5.064931
# 523    5.498  1622.304320  5.064878
# 524    5.510  1620.903611  5.064731
# 525    5.521  1620.855927  5.065103
# ...      ...          ...       ...
# 1009  10.687    38.231015  0.013356
# 1010  10.698    42.090416  0.005026
# 1011  10.708    40.827394  0.000238
# 1012  10.720    41.219592 -0.001259
# 1013  10.731    40.792823 -0.001054
#
# [493 rows x 3 columns]

# %%
df_drop = df.drop(index=[split_index_1, split_index_2, split_index_3])
# Rename the first column as "time"
# Rename the columns
df_drop.columns = ['Time', 'Force', '']

# Drop the third column
df_drop = df_drop.drop(columns=[''])
print(df_drop)
# Out:
#         Time      Force
# 0      0.006  39.324760
# 1      0.017  39.778948
# 2      0.026  41.922331
# 3      0.036  40.362477
# 4      0.048  41.080117
# ...      ...        ...
# 1009  10.687  38.231015
# 1010  10.698  42.090416
# 1011  10.708  40.827394
# 1012  10.720  41.219592
# 1013  10.731  40.792823
#
# [1011 rows x 2 columns]

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.plot(df_drop['Time'], df_drop['Force'], marker='o', linestyle='-')
plt.title('Distance over Time')
plt.xlabel('Timestamp')
plt.ylabel('Force')
plt.grid(True)
plt.show()

# %%
def main():
    for filename in os.listdir(input_folder):
        if filename.endswith(".csv"):
            csv_path = os.path.join(input_folder, filename)
            print("Processing video:", filename)
            
            # No need to close loading_bar here, it's automatically closed when exiting the "with" block

# %%
# Call the main function to start processing
if __name__ == "__main__":
    main()
